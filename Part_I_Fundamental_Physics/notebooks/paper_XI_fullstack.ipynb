# %% [markdown]
# # Paper XI - Full-stack supplementary reproduction
#
# Calls `run_paper_xi()` from `Part_II_Fundamental_Physics/supplementary_XI.py` and regenerates the Paper XI figures, tables, and checks.

# %%
import os
import sys
from pathlib import Path

HERE = Path.cwd().resolve()
search_roots = [HERE, *HERE.parents]
candidates = []
for base in search_roots:
    candidates.append(base)
    candidates.append(base / "Part_II_Fundamental_Physics")

PAPERS = None
for candidate in candidates:
    if (candidate / "supplementary_XI.py").exists():
        PAPERS = candidate
        break

if PAPERS is None:
    raise RuntimeError("Could not find Part_II_Fundamental_Physics/supplementary_XI.py")

ROOT = PAPERS.parent
os.chdir(PAPERS)
sys.path.insert(0, str(PAPERS))
sys.path.insert(0, str(ROOT))

from supplementary_XI import run_paper_xi

results = run_paper_xi(write_outputs=True, verbose=True)
results["output_dir"]

# %%
results.get("gate", results.get("summary", results))

# %% [markdown]
# CSV tables, checks, and figure files land in `Part_II_Fundamental_Physics/outputs/paper_XI/`.
